# %% [markdown]
# # Regex Assignment

# %% [markdown]
# In this assignment you're going to learn how to use Regular Expressions (regex) to extract and clean patterns from textual data. Regular expressions provide a special language to capture patterns in text. They can be infintely combined to extract *very* complex patterns under many conditions. Luckily for you, we will only go into the basics. In Python, the [`re`](https://docs.python.org/2/library/re.html) library provides us with a way of interpreting these patterns and using them for *search*.
#
# Let's look at some examples:

# %%
import re

some_text = "hello, world"
re.findall('\w', some_text)
# Out:
# ['h', 'e', 'l', 'l', 'o', 'w', 'o', 'r', 'l', 'd']

# %% [markdown]
# The above example simply matches each alphanumeric character (a through z and 0 through 9, abbreviated by `\w`) individually. If we want to find actual words, we need it to tell that we're actually looking for a *sequence*. This can be done using the `*`. Basically it tells regex to do these steps:
#
# - Start scanning the string
# - If you find any character matching (a-z or 0-9) start recording.
# - If you find any character that doesn't match this, stop recording.
# - Give me a list of all the sequences you recorded.

# %%
re.findall('\w*', some_text)
# Out:
# ['hello', '', '', 'world', '']

# %% [markdown]
# These 'empty' hits `'', ''` are empty because it finds a character that does not belong to the pattern you specified (e.g. `,`, whitespace, and the end of the string).

# %% [markdown]
# Of course, you can also only match letters (to clean data for example). By default regex searches for the **exact** order that you provide as a pattern, like so:

# %%
more_text = "abc cba abc bc ab"
re.findall("abc", more_text)
# Out:
# ['abc', 'abc']

# %% [markdown]
# If you just want to find anything including `a` or `b` (even `ba` or `ab`), you can encapsulate these between square brackets (`[ ]`). For example:

# %%
re.findall("[ab]*", more_text)
# Out:
# ['ab', '', '', '', 'ba', '', 'ab', '', '', 'b', '', '', 'ab', '']

# %% [markdown]
# Because it's pretty inconvenient to write `[abcdefhijklmnopqrstuvwxyz]` everyime, you can abbreviate this with `[a-z]`, similar to `[A-Z]` and `[0-9]`. Of course you can combine these as well (`[a-zA-Z0-9]`). This can be used for cleaning up data for example:

# %%
raw_text = "h3ll0, w0rld."
re.findall('[a-z]*', raw_text)
# Out:
# ['h', '', 'll', '', '', '', 'w', '', 'rld', '', '']

# %% [markdown]
# Whitespaces also count (just simply a space, like ` `). So say we want to split a text into words, we can do this by:

# %%
example_text= "So say we want to split a text into words, we can do this by:"
re.findall('[A-Za-z0-9]*[ ,.:]', example_text)
# Out:
# ['So ',
#  'say ',
#  'we ',
#  'want ',
#  'to ',
#  'split ',
#  'a ',
#  'text ',
#  'into ',
#  'words,',
#  ' ',
#  'we ',
#  'can ',
#  'do ',
#  'this ',
#  'by:']

# %% [markdown]
# Just quickly analyzing the code. We look for "any alphanumeric character" until we see "either whitespace, comma, period or colon". We can exclude this second group of punction marks in the output by encapsulating the `[A-Za-z0-9]*` part with brackets (`( )`). Like so:

# %%
re.findall('([A-Za-z0-9]*)[ ,.:]', example_text)
# Out:
# ['So',
#  'say',
#  'we',
#  'want',
#  'to',
#  'split',
#  'a',
#  'text',
#  'into',
#  'words',
#  '',
#  'we',
#  'can',
#  'do',
#  'this',
#  'by']

# %% [markdown]
# Some characters are also used as regex symbols (like `^`, `?` etc), and therefore need to be 'escaped' as this is called. This is done by prepending a `\ ` to the symbol as to indicate: THIS IS NOT PATTERN! So for example:

# %%
question_text = "why this question?"
re.findall('\?', question_text)
# Out:
# ['?']

# %% [markdown]
# Try to remove the `\ ` and see that it gives an error.
#
# Finally, you are also able to limit the amount of things you want to maximally read with operators like `+` (1 or more), `?` (none or 1), `{m}` (exactly the amount of $m$), and `{m,n}` from $m$ to $n$. E.g.:

# %%
pattern_text = "aaaaaaaaaaaaaaaaa bbbbbbbbbbbb ccccccc aaaaaaaaa bbbaaaa"
re.findall('a{4}', pattern_text)
# Out:
# ['aaaa', 'aaaa', 'aaaa', 'aaaa', 'aaaa', 'aaaa', 'aaaa']

# %%
re.findall('a{2,5}', pattern_text)
# Out:
# ['aaaaa', 'aaaaa', 'aaaaa', 'aa', 'aaaaa', 'aaaa', 'aaaa']

# %% [markdown]
# Note that by default, regex is 'greedy'. So if you define a minimum of two, and a maximum of five, it will always 'eat' until it reaches at least five. If you want it to be non-greedy, you include `?`. Like so:

# %%
re.findall('a{2,5}?', pattern_text)
# Out:
# ['aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa',
#  'aa']

# %% [markdown]
# As you can see, it now just always stops at 2. It's 'full' so to say once it has eaten two a's.
#
# There's a lot more to regex, but these are the very basic things (and as much as you will need for this assignment. Here's a convenient cheat sheet with most of the patterns:
#
# ![cheatsheet](http://tartley.com/wp-content/uploads/2011/10/Python-regular-expression-cheatsheet-0.3.0.png)

# %% [markdown]
# # Important BEFORE Starting

# %% [markdown]
# Please run the code below, it provides two handy functions to help you finish the assignments:

# %%
from IPython.core.display import display, HTML

def highlight_regex(matches, text):
    """Highlights the items in 'matches' in the provided 'text'."""
    for match in set(matches):
        text = text.replace(match, '<mark>' + match + '</mark>')
        text = text.replace('\n', '<br>')
    return display(HTML('<html>' + text + '</html>'))

def submit_answers(name, results):
    """Writes you answers to a txt file so we can check them."""
    answer_file = open('regex-{0}.txt'.format(name), 'w', encoding='utf-8')
    answer_file.write('\n'.join(results) if name != 'html' else results)
    answer_file.close()

# %% [markdown]
# ## Find Hashtags in Tweets
#
# We'll start of nice and easy. For the first assignment you are asked to find a number of hashtags in tweets. The tweets are from [Chris Manning](https://twitter.com/chrmanning) --- you are allowed to use his page as a visual reference. We will use the `findall` command, which will return a list of all hits of the pattern.

# %% [markdown]
# Now it's your turn.
#
# ### Task 1
# *Find all hashtags in a user's Twitter timeline.*
#
# Please note that when there are consecutive hashtags, these are matched **independently**.

# %%
import re

twitter_file = open('data/tweets.md', encoding='utf-8').read()

# ONLY EDIT THIS PART

hashtags = re.findall('#', twitter_file)  # edit the pattern '#'

# -------------------

print(hashtags)
highlight_regex(hashtags, twitter_file)

submit_answers('hashtags', hashtags)
# Out:
# ['#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#', '#']
# <html> In reply to Florian Laws<br> Christopher Manning ‏@chrmanning  Aug 30<br>.@florianlaws I encountered this too—token level easy, subsequence level hard—can sum head of n-best list, but can clever person do better?<br>1 retweet 3 likes<br>Reply   Retweet  1   <br>Like 3  <br>More<br> Christopher Manning Retweeted<br> Hilary Mason ‏@hmason  Aug 30<br>Hilary Mason Retweeted Samuel Arbesman<br>I hope we are moving from a default assumption of the impartiality of algorithms to one of deeper critical analysis.Hilary Mason added,<br>Samuel Arbesman @arbesman<br>“we’re left with algorithms performing a job they’re still ill-equipped to handle” <mark>#</mark>Overcomplicated? http://www.theverge.com/2016/8/30/12702478/facebook-trending-topics-fake-news-megyn-kelly …<br>76 retweets 118 likes<br>Reply   Retweet  76   <br>Like 118  <br>More<br> Christopher Manning Retweeted<br> Stanford Engineering ‏@StanfordEng  Aug 30<br>We need computers that can really understand human language argues @chrmanning: http://stanford.io/2a46Mio   <mark>#</mark>FutureofAI<br><br>19 retweets 29 likes<br>Reply   Retweet  19   <br>Like 29  <br>More<br>Promoted Tweet<br> Aha! ‏@aha_io  Aug 21<br>1. Boss wants your roadmap<br>2. Panic<br>3. Use Aha! <br>4. Be happy<br>http://www.aha.io/software/roadmap-template?utm_source=twitter&utm_medium=sponsored&utm_campaign=twtr_dev_lp …<br><br> Promoted<br>11 retweets 118 likes<br>Reply   Retweet  11   <br>Like 118  <br>More<br> Christopher Manning ‏@chrmanning  Aug 27<br>Christopher Manning Retweeted CSAIL at MIT<br>Fond memories of VAX assembly—nicest ever CISC architectureChristopher Manning added,<br><br>CSAIL at MIT @MIT_CSAIL<br>Happy bday to the minicomputer pioneer Gordon Bell, who also developed VAX architecture: http://bit.ly/2agFRiL  <br>3 retweets 7 likes<br>Reply   Retweet  3   <br>Like 7  <br>More<br> Christopher Manning ‏@chrmanning  Aug 13<br>My kid Casey spent the summer at <mark>#</mark>makeschool making an iOS Swift puzzler game. Check it out!<br>https://appsto.re/us/tNlheb.i <br><br>3 retweets 17 likes<br>Reply   Retweet  3   <br>Like 17  <br>More<br> Christopher Manning Retweeted<br> Kyunghyun Cho ‏@kchonyc  Aug 7<br>@chrmanning at the tutorial in <mark>#</mark>nmt at <mark>#</mark>acl2016berlin<br><br>4 retweets 9 likes<br>Reply   Retweet  4   <br>Like 9  <br>More<br> Christopher Manning ‏@chrmanning  Aug 6<br>I'm in Berlin, all ready for <mark>#</mark>acl2016berlin!<br>0 retweets 42 likes<br>Reply   Retweet    <br>Like 42  <br>More<br>Christopher Manning followed ac, iclr2017, Kyunghyun Cho and 2 others<br><br>User Actions <br> Follow<br>ac Verified account<br>@alessiacara<br> <br><br>User Actions <br> Follow<br>iclr2017<br>@iclr2017<br>Official account for ICLR17, a venue for researchers concerned with questions surrounding how we can best learn representations of data and its…<br> Christopher Manning Retweeted<br> Jussi Karlgren ‏@jussikarlgren  Jul 20<br>Aya Soffer announces "The Summer of NLP", referring back to Hadar (and implicitly to Monday's keynote by @chrmanning ) <mark>#</mark>SIGIR2016<br>5 retweets 1 like<br>Reply   Retweet  5   <br>Like 1  <br>More<br> Christopher Manning ‏@chrmanning  Jul 19<br>I’ve put up the slides for my <mark>#</mark>sigir2016 invited talk at http://nlp.stanford.edu/~manning/talks/SIGIR2016-Deep-Learning-NLI.pdf … – including a voiceover for the last slide so it‘s clearer.<br>144 retweets 208 likes<br>Reply   Retweet  144   <br>Like 208  <br>More<br> Christopher Manning Retweeted<br> Bhaskar Mitra ‏@UnderdogGeek  Jul 18<br>@chrmanning : Next year deep learning will dominate SIGIR completely, but beware of the hype.<br><br>20 retweets 21 likes<br>Reply   Retweet  20   <br>Like 21  <br>More<br>Promoted Tweet<br> F1000Prime ‏@F1000Prime  46m46 minutes ago<br>Are you a researcher? Find out how to easily save references while you browse.<br><br> Promoted<br>0 retweets 0 likes<br>Reply   Retweet    <br>Like  <br>More<br> Christopher Manning Retweeted<br> Aldo Lipa ...

# %% [markdown]
# ## Generating New Features (DSBG only)

# %% [markdown]
# As we've seen in the Social Data Science lecture, sometimes you are provided with textual features that cannot be interpreted by the software you are using (in this case WEKA). The Titanic dataset is a perfect example of this. If we take a look at the rows in the `.arff` file (here saved as `.csv`), we can see that the names of the passengers have some information:

# %%
import csv

reader = csv.reader(open('data/titanic.csv', encoding='utf-8'))
for i, row in enumerate(reader):
    if i == 10:
        break
    else:
        print(row[3])
# Out:
# Braund - Mr. Owen Harris
# Cumings - Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen - Miss. Laina
# Futrelle - Mrs. Jacques Heath (Lily May Peel)
# Allen - Mr. William Henry
# Moran - Mr. James
# McCarthy - Mr. Timothy J
# Palsson - Master. Gosta Leonard
# Johnson - Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser - Mrs. Nicholas (Adele Achem)

# %% [markdown]
# So apparently they noted 'titles' for certain passengers, which might indicate if they are maried, have some rank, this kind of information. They are coded in a very distinct format, so they should be easy to extract.

# %% [markdown]
# ### Task 2
# *Find all titles in the Titanic dataset.*

# %%
import re

titanic_file = open('data/titanic.csv', encoding='utf-8').read()

# ONLY EDIT THIS PART

titles = re.findall('\.', titanic_file)  # edit the pattern '\.' -- DONT REMOVE THE ESCAPE! :)

# -------------------

titles = set(titles)
print(titles)
highlight_regex(titles, titanic_file)

submit_answers('titles', titles)
# Out:
# {'.'}
# <html>1,0,3,"Braund - Mr<mark>.</mark> Owen Harris",male,22,1,0,"A/5 21171",7<mark>.</mark>25,?,S<br>2,1,1,"Cumings - Mrs<mark>.</mark> John Bradley (Florence Briggs Thayer)",female,38,1,0,"PC 17599",71<mark>.</mark>2833,C85,C<br>3,1,3,"Heikkinen - Miss<mark>.</mark> Laina",female,26,0,0,"STON/O2<mark>.</mark> 3101282",7<mark>.</mark>925,?,S<br>4,1,1,"Futrelle - Mrs<mark>.</mark> Jacques Heath (Lily May Peel)",female,35,1,0,113803,53<mark>.</mark>1,C123,S<br>5,0,3,"Allen - Mr<mark>.</mark> William Henry",male,35,0,0,373450,8<mark>.</mark>05,?,S<br>6,0,3,"Moran - Mr<mark>.</mark> James",male,?,0,0,330877,8<mark>.</mark>4583,?,Q<br>7,0,1,"McCarthy - Mr<mark>.</mark> Timothy J",male,54,0,0,17463,51<mark>.</mark>8625,E46,S<br>8,0,3,"Palsson - Master<mark>.</mark> Gosta Leonard",male,2,3,1,349909,21<mark>.</mark>075,?,S<br>9,1,3,"Johnson - Mrs<mark>.</mark> Oscar W (Elisabeth Vilhelmina Berg)",female,27,0,2,347742,11<mark>.</mark>1333,?,S<br>10,1,2,"Nasser - Mrs<mark>.</mark> Nicholas (Adele Achem)",female,14,1,0,237736,30<mark>.</mark>0708,?,C<br>11,1,3,"Sandstrom - Miss<mark>.</mark> Marguerite Rut",female,4,1,1,"PP 9549",16<mark>.</mark>7,G6,S<br>12,1,1,"Bonnell - Miss<mark>.</mark> Elizabeth",female,58,0,0,113783,26<mark>.</mark>55,C103,S<br>13,0,3,"Saundercock - Mr<mark>.</mark> William Henry",male,20,0,0,"A/5<mark>.</mark> 2151",8<mark>.</mark>05,?,S<br>14,0,3,"Andersson - Mr<mark>.</mark> Anders Johan",male,39,1,5,347082,31<mark>.</mark>275,?,S<br>15,0,3,"Vestrom - Miss<mark>.</mark> Hulda Amanda Adolfina",female,14,0,0,350406,7<mark>.</mark>8542,?,S<br>16,1,2,"Hewlett - Mrs<mark>.</mark> (Mary D Kingcome) ",female,55,0,0,248706,16,?,S<br>17,0,3,"Rice - Master<mark>.</mark> Eugene",male,2,4,1,382652,29<mark>.</mark>125,?,Q<br>18,1,2,"Williams - Mr<mark>.</mark> Charles Eugene",male,?,0,0,244373,13,?,S<br>19,0,3,"Vander Planke - Mrs<mark>.</mark> Julius (Emelia Maria Vandemoortele)",female,31,1,0,345763,18,?,S<br>20,1,3,"Masselmani - Mrs<mark>.</mark> Fatima",female,?,0,0,2649,7<mark>.</mark>225,?,C<br>21,0,2,"Fynney - Mr<mark>.</mark> Joseph J",male,35,0,0,239865,26,?,S<br>22,1,2,"Beesley - Mr<mark>.</mark> Lawrence",male,34,0,0,248698,13,D56,S<br>23,1,3,"McGowan - Miss<mark>.</mark> Anna 'Annie'",female,15,0,0,330923,8<mark>.</mark>0292,?,Q<br>24,1,1,"Sloper - Mr<mark>.</mark> William Thompson",male,28,0,0,113788,35<mark>.</mark>5,A6,S<br>25,0,3,"Palsson - Miss<mark>.</mark> Torborg Danira",female,8,3,1,349909,21<mark>.</mark>075,?,S<br>26,1,3,"Asplund - Mrs<mark>.</mark> Carl Oscar (Selma Augusta Emilia Johansson)",female,38,1,5,347077,31<mark>.</mark>3875,?,S<br>27,0,3,"Emir - Mr<mark>.</mark> Farred Chehab",male,?,0,0,2631,7<mark>.</mark>225,?,C<br>28,0,1,"Fortune - Mr<mark>.</mark> Charles Alexander",male,19,3,2,19950,263,"C23 C25 C27",S<br>29,1,3,"O'Dwyer - Miss<mark>.</mark> Ellen 'Nellie'",female,?,0,0,330959,7<mark>.</mark>8792,?,Q<br>30,0,3,"Todoroff - Mr<mark>.</mark> Lalio",male,?,0,0,349216,7<mark>.</mark>8958,?,S<br>31,0,1,"Uruchurtu - Don<mark>.</mark> Manuel E",male,40,0,0,"PC 17601",27<mark>.</mark>7208,?,C<br>32,1,1,"Spencer - Mrs<mark>.</mark> William Augustus (Marie Eugenie)",female,?,1,0,"PC 17569",146<mark>.</mark>5208,B78,C<br>33,1,3,"Glynn - Miss<mark>.</mark> Mary Agatha",female,?,0,0,335677,7<mark>.</mark>75,?,Q<br>34,0,2,"Wheadon - Mr<mark>.</mark> Edward H",male,66,0,0,"C<mark>.</mark>A<mark>.</mark> 24579",10<mark>.</mark>5,?,S<br>35,0,1,"Meyer - Mr<mark>.</mark> Edgar Joseph",male,28,1,0,"PC 17604",82<mark>.</mark>1708,?,C<br>36,0,1,"Holverson - Mr<mark>.</mark> Alexander Oskar",male,42,1,0,113789,52,?,S<br>37,1,3,"Mamee - Mr<mark>.</mark> Hanna",male,?,0,0,2677,7<mark>.</mark>2292,?,C<br>38,0,3,"Cann - Mr<mark>.</mark> Ernest Charles",male,21,0,0,"A<mark>.</mark>/5<mark>.</mark> 2152",8<mark>.</mark>05,?,S<br>39,0,3,"Vander Planke - Miss<mark>.</mark> Augusta Maria",female,18,2,0,345764,18,?,S<br>40,1,3,"Nicola-Yarred - Miss<mark>.</mark> Jamila",female,14,1,0,2651,11<mark>.</mark>2417,?,C<br>4 ...

# %% [markdown]
# ## Finding E-mails
#
# In this part, you are dealing with `.csv` data. This *comma-separated values* format is commonly used to store flat table data. Quick sample:
#
#     "1","jan engelen","j.a.a.engelen@tilburguniversity.edu"
#     "2","emannuel keuleers","e.a.keuleers@tilburguniversity.edu"
#     "3","chris emmery","cmry@protonmail.com"
#
# This usually works pretty well, and you can conveniently call the number of the row (starting from 0) you want to see in your favourite programming language. Python uses the `csv` library for this. Basically you just open the file like we did before, and you pass it to the `csv.reader`. This reader will interpret the format, and try to make sense of the field's boundaries (here we use `"`). The sample above I've saved under `data/sample-mails.csv`, we can open it up and list the emails like so:

# %%
import csv

reader = csv.reader(open("data/sample-mails.csv", encoding='utf-8'))

for line in reader:
    print(line[2])  # notice that 0 would be the numbers, 1 the names
# Out:
# j.a.a.engelen@tilburguniversity.edu
# e.a.keuleers@tilburguniversity.edu
# cmry@protonmail.com

# %% [markdown]
# Truth is, that sometimes these `.csv` files are not so neatly structured (especially when written by hand or messed up by software). The same holds true for the file saved under `data/emails.csv`. Let's open it up and check the first few rows:

# %%
reader = csv.reader(open('data/emails.csv', encoding='utf-8'))

for i, line in enumerate(reader):
    if i == 10:
        break
    else:
        print(line)
# Out:
# ['Fallon Olesen"fallonolesen@bing.com', 'RABY~A2a', '5d0c757513f62a706bdda1e0715540cf"']
# ['Agrippa Brandon', 'agrippabran@geocities.com', '6aWU,UrY?uVA', '2b44d6ab7313e4cc07ed81ae3532b088']
# ['Khalid Wann', 'kha.wan@yahoo.com', 'XuJaZaQ', '97865ab5c1942dd713f94ff6305032ef']
# ['Aden Odum', 'ade_odu@webmail.com', '#ajy5ej"', '9df0b29a273d52721b307a5297eba414']
# ['Amit Schlabach"', 'ami_sc@info.com', '@A5UNu.YXU', '7f103e43d0d41fd68b9902947d63ffd3']
# ['Adelinda Koepke', 'ade-koepke@toodles.com', '=UqeHEGaXE', '3bc74e6518600ce8628c66ed6446717b']
# ['Adila Kohut', 'adila_koh@toodles.com', 'myBU$uGaHE)a', '1ee5691a325f20ca360b15791a0c05e5']
# ['Talfryn Abeyta', '\'talfry-abeyta@yoohoo.com""Zare~Ete"', '044c01baf0887027784064db7482eb92']
# ["Corbin Silvis'cor_silvis@msn.com", 'Ba-UnY~YgeLU', '849ed89eec82fc3b2972a1fb5e25bc46"Rhoda Richman', 'rhoda-ri@myspace.com', 'zyGEDYGynUZy', 'd9d48f6cfe010fe8da0732b403d9b648']
# ['Malak Beeler', 'malak.beeler@yoohoo.com', '(e9unA?ERy2A', '4ac773d3b3e388d8b49844ddf1a58575']

# %% [markdown]
# As we can see, not all rows behave like they should, sometimes the email is merged with the name, and the second to last line merges two entries together. Luckily, we can still retrieve a list of all the emails using regular expressions!
#
# ### Task 3
# *Extend the regex below to recover as many of the 50 emails as you can.*
#
# Note that the output should cover (highlighted in the output) the **whole** email address, not just the `@` or `@hotmail.com` part or whatever.

# %%
import re

email_file = open('data/emails.csv', encoding="utf-8").read()

# ONLY EDIT THIS PART

emails = re.findall('@', email_file)  # edit the pattern '@'

# -------------------

print(emails)
highlight_regex(emails, email_file)

submit_answers('emails', emails)
# Out:
# ['@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@', '@']
# <html>"Fallon Olesen""fallonolesen<mark>@</mark>bing.com","RABY~A2a",5d0c757513f62a706bdda1e0715540cf"<br>"Agrippa Brandon","agrippabran<mark>@</mark>geocities.com","6aWU,UrY?uVA","2b44d6ab7313e4cc07ed81ae3532b088"<br>"Khalid Wann","kha.wan<mark>@</mark>yahoo.com","XuJaZaQ","97865ab5c1942dd713f94ff6305032ef"<br>"Aden Odum","ade_odu<mark>@</mark>webmail.com",#ajy5ej","9df0b29a273d52721b307a5297eba414"<br>Amit Schlabach","ami_sc<mark>@</mark>info.com","<mark>@</mark>A5UNu.YXU","7f103e43d0d41fd68b9902947d63ffd3"<br>"Adelinda Koepke","ade-koepke<mark>@</mark>toodles.com","=UqeHEGaXE","3bc74e6518600ce8628c66ed6446717b"<br>"Adila Kohut","adila_koh<mark>@</mark>toodles.com","myBU$uGaHE)a","1ee5691a325f20ca360b15791a0c05e5"<br>"Talfryn Abeyta",'talfry-abeyta<mark>@</mark>yoohoo.com""Zare~Ete","044c01baf0887027784064db7482eb92"<br>"Corbin Silvis'cor_silvis<mark>@</mark>msn.com","Ba-UnY~YgeLU","849ed89eec82fc3b2972a1fb5e25bc46""Rhoda Richman","rhoda-ri<mark>@</mark>myspace.com","zyGEDYGynUZy","d9d48f6cfe010fe8da0732b403d9b648"<br>"Malak Beeler","malak.beeler<mark>@</mark>yoohoo.com",(e9unA?ERy2A,"4ac773d3b3e388d8b49844ddf1a58575"<br>"Anatole Abeyta","anatolabey<mark>@</mark>hotmail.com","2ybY?ES","cb5657c3f07d8223897cbac4d850d9ba"<br>"Kimba Mccann","kimbamc<mark>@</mark>yahoo.com","jEXu&aT","dd116d02ca40d860b4c63be81c3fb252"<br>"Jacoba Hipolito","ja-hipol<mark>@</mark>webmail.com","7U[umaGuh","fef8c95f5e8fdb1f53b43a1dd2f55616"<br>"Prabhakar Kohut",prabkohu<mark>@</mark>mail.com","^U%a~yBu/","841cb3642d195b55ba02471c555669b9"<br>"Fuensanta Burkes","fuensant.bu<mark>@</mark>yahoo.ca""-U$U4eJy}eN","a42e0fb8dfff61b8fde27ff396c1da3c"<br>"Thorkell Mallard","thorma<mark>@</mark>infoseller.vze.com","*AMu^uJu","32e88bdd0d2d4d980fb170991a68dfb4"<br>"Louie Canada","loui_cana<mark>@</mark>yahoo.com","RU^E/Em"64337e61a51b2ad3f0fcab2636301c45"<br>"Malak Kolb","mala-kol<mark>@</mark>mail.com","9U7yseRU&y~","9e23bdfd54b8aab7f1b653f4ebc92248"<br>"Morty Zubia","morty-zubi<mark>@</mark>webmail.com","bU`y*ygA[","665eda687d6056ad8b1c76309e6ec924"<br>"Louie Grote","loui-grot<mark>@</mark>mail.co.uk","VeQYBADANa","ecbf4697010ee8d92a2e2ed7ce44b980""Akiyama Michael","aki_mich<mark>@</mark>yahoo.ca","RUQa%E~a9","f16d3cdc16d7bf82e82f0765478b0524"<br>"Jelena Willoughby","jel_wil<mark>@</mark>infoseller.com","[Y!aJu,upU5""0a8e3c8ebc77ab81a9ecd61cc42d3189"<br>"Lissa Browning",li-browni<mark>@</mark>webmail.com","te[y8a?e","d2ae5ea37266b479f00632d92e000abf"<br>Zena Pereira",'ze.pereir<mark>@</mark>yahoo.com","qy!yda5","b95f9b20bbc54cc327fc2141e896f63a"<br>"Gisela Hull","gi_hul<mark>@</mark>webmine.com","Re[E%uLA{y^a","7149276ab2e10dce6b96487583f81586"<br>"Adila Deel","adil_deel<mark>@</mark>freespace.com","ta?URy_a<mark>@</mark>e+","5d953a8a366ff570117a0f69cdefabba"<br>"Harish Rackley","harish_rack<mark>@</mark>mail.com","Xa]Y]E,,"17834517dca59afc14c6f83502acfe6f"<br>"Jeffery Spates","jeffery_spat<mark>@</mark>msn.com","WEXeLE{uzA9","5b8cfff185a7ea385e5d9c30acf120f8"<br>"Jolan Briceno","jol-brice<mark>@</mark>yahoo.ca","LAzY)uZ","0764f6e3f8da5972dff86c4bf6165d14"<br>"Mimosa Cuellar,"mimoscuel<mark>@</mark>infoseller.com","ba%y_eZug","cccb0e2ab313416766fed1e80a29528f"<br>"Semele Zavala","sezav<mark>@</mark>booksmart.com","Nu<mark>@</mark>u!UZ","9e1462039aad3b46b8de72617206196f"<br>"Mahabala Deel","mahabal_Dee<mark>@</mark>carmag.com","JEzESaQAm","8447e055e75b453263eeeb0fe98128b3<br>"Gisela Zubia","gis_zubi<mark>@</mark>carmag.com","syje+AWy","bcaaf0137a9dfcaf5c87162bcf3d9f46"<br>Zenia Cordoba","ze-cordo<mark>@</mark>linux.com","qyDU~e_u$A","09bc56290a42293881af9972416af21e"<br>"Valerie Abalos","va_abal<mark>@</mark>geocities.com',"8AgA#U-U7Uze","bbf688139d2e1ff0896aa49d69ac1210"<br>"Adama Dillard","adama_di<mark>@</mark>yahoo.com","$UjyQAB","e0a0aa2e5bbc117514741ef644e549bd"<br>"Tusti Walters",tu-wa<mark>@</mark>yahoo.ca","SUraLYJY]U","a50c5b8e5ad18df5d6c5c4b15378d7fa"<br>"Mingmei Haberman'"mingm-haberman<mark>@</mark>booksmart.com","6YMu5Ys","0e38162b7a1a63219f4fbae3 ...

# %% [markdown]
# ## Cleaning HTML

# %% [markdown]
# An example of a task that can be solved with regex is cleaning your data of any junk that pollutes your nice running piece of natural language. Maybe most notorious are `.html` files: the structure of webpages. HTML includes a lot of `<tag>something</tag>`. For this part, you are going to clean [this](https://tweakers.net/reviews/4867/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooit.html) webpage. We take Tweakers.net because it has a relatively neat HTML structure (compared to other monstrosities of web developent). For this task we will use `sub`. Sub 'substitutes' a certain pattern with a string. So say we would want to remove all numbers from a string, we would do:

# %%
number_text = "123 assf 1231 oidsjg 093463"
re.sub('[0-9]', '', number_text)
# Out:
# ' assf  oidsjg '

# %% [markdown]
# Or we convert them to `_` for example:

# %%
number_text = "123 assf 1231 oidsjg 093463"
re.sub('[0-9]', '_', number_text)
# Out:
# '___ assf ____ oidsjg ______'

# %% [markdown]
# To keep things neat, we can just use multiple lines:

# %%
number_text = "123 assf 1231 oidsjg 093463"
text = re.sub('[0-9]', '_', number_text)
text = re.sub(' ', '', text)
text
# Out:
# '___assf____oidsjg______'

# %% [markdown]
# ### Task 4
# *Clean the HTML of the article so it shows as little junk as possible (i.e. at best only the article).*
#
# Please don't waste too much time on this assignment, it's a **very** hard task to solve with regex.

# %%
import re

html = open('data/acer-swift.html', encoding='utf-8').read()

html = re.sub('\.', '', html)  #
html = re.sub('\.', '', html)  # use more lines to keep the rules simple

print(html)

submit_answers('html', html)
# Out:
# <!doctype html><!-- (c) 1998 - 2016 de Persgroep Online Services BV -->
# <html lang="NL">
# 	<head>
# 		<meta http-equiv="content-type" content="text/html; charset=iso-8859-15">
# 		<meta name="referrer" content="origin-when-cross-origin">
# 		<meta name="viewport" content="width=device-width">
# 		<meta name="description" content="Acer onthulde op IFA een nieuwe lijn notebooks onder de naam Swift Volgens de fabrikant is het 13,3&quot; Swift 7-model de dunste notebook van dit moment">
# 		<meta property="fb:app_id" content="188199811217403">
# 		<meta property="og:site_name" content="Tweakers">
# 		<meta property="og:locale" content="nl_NL">
# 		<meta property="og:type" content="article">
# 		<meta property="og:title" content="Acer Swift 7 Preview: de dunste 13,3&quot;-notebook ooit">
# 		<meta property="og:url" content="https://tweakersnet/reviews/4867/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml">
# 		<meta property="og:description" content="Acer onthulde op IFA een nieuwe lijn notebooks onder de naam Swift Volgens de fabrikant is het 13,3&quot; Swift 7-model de dunste notebook van dit moment">
# 		<meta property="og:image" content="https://ictweakimgnet/ext/i/1303211688png">
# 		<meta name="twitter:card" content="summary_large_image">
# 		<meta name="twitter:site" content="@tweakers">
# 		<meta name="twitter:creator" content="@woutf">
# 		<meta name="twitter:image" content="https://ictweakimgnet/ext/i/2001218809jpeg">
# 		<base href="https://tweakersnet/">
# 		<title>Acer Swift 7 Preview - Tweakers</title>
# 		<link rel="navigator" title="Spring voorbij navigatie" href="https://tweakersnet/reviews/4867/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml#contentArea">
# 		<link rel="canonical" href="https://tweakersnet/reviews/4867/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml">
# 		<link rel="shortcut icon" type="image/x-icon" href="https://tweakersnet/faviconico">
# 		<link rel="alternate" title="Tweakers Mixed RSS feed" type="application/rss+xml" href="https://tweakersnet/feeds/mixedxml">
# 		<link rel="alternate" title="Tweakers Reviews RSS feed" type="application/rss+xml" href="https://tweakersnet/feeds/reviewsxml">
# 		<script>
# 			var relaxedDomain='tweakersnet',tweakersConfig={"BaseURL":"https:\/\/tweakersnet\/","TnetBaseURL":"https:\/\/tweakersnet\/","ForumBaseURL":"https:\/\/gatheringtweakersnet\/","ImgURL":"https:\/\/tweakimgnet\/","sidName":"TnetID","UserID":420420,"compare":{"initialCompareBasket":[],"defaultCompareUrl":"https:\/\/tweakersnet\/pricewatch\/compare\/0\/","compareMax":50,"timestamp":1473068928},"usabillaScriptId":"0868022af325js"};
# 			try{documentdomain=relaxedDomain}catch(e){relaxedDomain=''};
# 			documentdocumentElementclassName='js';
# 		</script>
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/maincss?1471954818" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/layoutcss?1468320567" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/reactiescss?1467100142" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/articlescss?1467100142" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/tweakbasecss?1467100142" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/imageviewercss?1467100142" type="text/css" media="screen, handheld, projection">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/responsive_bcss?1468570412" type="text/css" media="(max-width: 1000px),(max-device-width: 1000px) and (orientation: portrait),(max-device-width: 767px) and (orientation: landscape)">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/responsive_ccss?1468570412" type="text/css" media="(max-width: 767px),(max-device-width: 767px) and (orientation: portrait),(max-device-width: 499px) and (orientation: landscape)">
# 		<link rel="stylesheet" href="https://tweakimgnet/x/min/responsive_dcss?1470655647" type="text/css" media="(max-width: 499px),(max-device-width: 499px) and (orientation: portrait)">
# 		<style id="customBgCss">#contentArea{border:1px solid}body,#bottom divhr,#entity,#heroBlock,#searchbar,galleryHeadingContainer,pageTabsContainer,notificationsContainer,#contentMenu{background-color:rgb(237,238,238)}#contentArea,#top,#mainSearch,#entity>div,entityHeader thumb,galleryHeading thumb,pageTabs li,#heroBlock,#contentMenu menu{border-color:rgb(207,208,208)}#mainSearch:hover{border-color:rgb(175,176,176)}</style>
# 		<script src="https://tweakimgnet/x/min/generaljs?1468320567"></script>
# 		<script src="https://tweakimgnet/x/min/frontpagejs?1470655646"></script>
# 		<script src="https://tweakimgnet/x/min/compare_storagejs?1470137748"></script>
# 		<script src="https://tweakimgnet/x/min/responsivejs?1468320568"></script>
# 		<script src="https://tweakimgnet/x/min/reactiesjs?1462880671"></script>
# 		<script src="https://tweakimgnet/x/min/rml_toolbarjs?1468320568"></script>
# 		<script src="https://tweakimgnet/x/min/articlesjs?1451997671"></script>
# 		<script src="https://tweakimgnet/x/responsive/articlejs?1470744218"></script>
# 		<script src="https://tweakimgnet/x/min/imageviewerjs?1451997671"></script>
# 		<script src="https://tweakimgnet/x/min/bannersjs?1470137748"></script>
# 		<script src="https://tweakimgnet/x/min/modjs?1465889648"></script>
# 		<script>
# 			(function(g,a){
# 				g['GoogleAnalyticsObject']=a;g[a]=g[a]||function(){
# 				(g[a]q=g[a]q||[])push(arguments)},g[a]l=1*new Date();
# 				loadJS('//wwwgoogle-analyticscom/analyticsjs')
# 			})(window,'_ga');
# 			_ga('create', 'UA-57798-5', 'auto', {'legacyCookieDomain': 'tweakersnet'});_ga('set', 'forceSSL', true);_ga('set', 'anonymizeIp', true);_ga('set', 'dimension1', 'Reviews');_ga('set', 'dimension2', 'core');_ga('send', 'pageview')
# 		</script>
# 		<script>
# 			var _wtq=[['_init',{"trackId":"318816705845986","trackDomain":"vnumedia01webtrekknet","domain":"tweakersnet;gatheringtweakersnet","cookie":"1","mediaCode":"wt_mc","contentId":"reviews\/article\/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooit","contentGroup":{"1":"tweakersnet","2":"Reviews","3":"Computers","4":"Computers","5":"Laptops","6":"Preview"},"executePluginFunction":"wt_urlCampaignMapper","customParameter":{"1":"A","3":1472990400,"4":"ifa 2016","5":"Acer","6":"Wout Funnekotter","7":"Acer Swift 7 Preview: de dunste 13,3\"-notebook ooit"},"customSessionParameter":{"1":"logged_in"}}],['_trackPage']];
# 			loadJS('https://tweakimgnet/x/vendor/webtrekk/webtrekk_v4js?1462880680');
# 		</script>
# 		<!-- START BANNERS -->
# 		<script>
# 			if (windowBannerManager)
# 			{
#              loadJS('//wwwgoogletagservicescom/tag/js/gptjs',BannerManagergoogleTagLoadCheck);
# 				BannerManagersetAdsenseVars('pub-6863650218525502','https:\/\/tweakersnet\/reviews\/4867\/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml');
# 				BannerManagersetSectionPath('/7455/tweakers/tweakerssite-large/computers/reviews_redactioneel/detail');
# 				BannerManagersetUseAsync(true);
# 				BannerManagersetTargets({"kw":["laptops"],"brand":["acer"],"tag":["ifa_2016"],"itemid":"18-4867"});
# 				BannerManageraddTag('tb',[[468,60],[728,90],[970,90],[970,250],[980,120]],{"targeting":{"positie":"top1"}});
# 				BannerManageraddTag('re',[[300,250],[300,600]],{"targeting":{"positie":"mid1"}});
# 				BannerManageraddTag('ac',[[360,300],[468,60],[620,349]],{"targeting":{"positie":"advertorial2","pos":3},"replacement":{"type":"as_normal","slot":"5436402013","provider":"adsense"}});
# 				BannerManageraddTag('ist',[[1,1]],{"targeting":{"positie":"layer1"}});
# 				BannerManagerenableTags();
# 			}
# 		</script>
# 		<!-- END BANNERS -->
#
# 	</head>
# 	<body class="customColor" itemscope itemtype="http://schemaorg/Article">
# 		<div id="top">
# 			<div id="menuwrapper">
# 				<div id="menubar">
# 					<div id="menu">
# 						<div class="leftSidebarToggle"></div>
# 						<div id="logo"><a href="https://tweakersnet/"></a></div>
# 						<b class="sitename">Tweakers</b>
#
# 			<ul id="navMenu">
# 				<li class="frontpage"><a href="https://tweakersnet/">Frontpage</a></li>
# 				<li><a href="https://tweakersnet/nieuws/">Nieuws</a></li>
# 				<li class="active"><a href="https://tweakersnet/reviews/">Reviews</a></li>
# 				<li><a href="https://tweakersnet/pricewatch/">Pricewatch</a></li>
# 				<li><a href="https://tweakersnet/aanbod/">Vraag &amp; Aanbod</a></li>
# 				<li><a href="https://gatheringtweakersnet/">Forum</a></li>
# 				<li class="more last"><span>Meer</span>
# 					<div>
# 						<ul>
# 							<li><a href="https://tweakersnet/video/">Video</a></li>
# 							<li><a href="https://tweakersnet/downloads/">Downloads</a></li>
# 							<li class="non-responsive"><a href="https://wwwitbanennl/?utm_source=tweakersnet&amp;utm_medium=tekstlink&amp;utm_campaign=tweakers_navigatie" rel="external">IT Banen</a></li>
# 							<li><a href="https://tweakersnet/categorie/892/it-pro/">IT Pro</a></li>
# 							<li class="non-responsive"><a href="https://tweakersnet/gallery/" rel="nofollow">Profielen</a></li>
# 							<li class="non-responsive"><a href="https://tweakblogsnet/">Tweakblogs</a></li>
# 							<li class="non-responsive"><a href="https://tweakersnet/acties/">Acties</a></li>
# 							<li><a href="https://tweakersnet/aboshop/" id="subscriptionShopUrl">Word Abonnee</a></li>
# 							<li class="non-responsive"><a href="https://tweakersnet/info/over_tweakers/">Over Tweakers</a></li>
# 						</ul>
# 					</div>
# 				</li>
# 			</ul>
# 				<div class="rightSidebarToggle ">
# 					<span id="totalNotificationsCount" class="newNotificationsCount">0</span>
# 				</div>
# 				<ul id="userbar" class="loggedin">
# 					<li class="icon search"><a id="searchPopupButton">Zoeken</a></li>
# 					<li class="more last"><span class="username">fazzeh</span>
# 						<div>
# 							<ul class="profileNavigation">
# 								<li><a href="https://tweakersnet/gallery/420420/">Mijn profiel</a></li>
# 								<li class="indent more"><span>Activiteit</span>
# 									<div>
# 										<ul>
# 											<li><a href="https://tweakersnet/search/?reactionSearch%5Btype%5D=username&amp;reactionSearch%5BsearchString%5D=fazzeh">Reacties</a></li>
# 											<li><a href="https://gatheringtweakersnet/forum/find/poster/420420/messages">Forumposts</a></li>
# 											<li><a href="https://tweakersnet/productreview/user/420420/">Productreviews</a></li>
#
# 										</ul>
# 									</div>
# 								</li>
# 								<li class="indent"><a href="https://tweakersnet/aanbod/admanager/">Advertenties</a></li>
# 								<li class="indent"><a href="https://tweakersnet/mytnet/fotoalbum/">Fotoalbum</a></li>
# 								<li class="indent"><a href="https://tweakersnet/mytnet/storage/">Privatestorage</a></li>
# 								<li class="indent"><a href="https://tweakersnet/gallery/420420/inventaris/">Inventaris</a></li>
# 								<li class="indent"><a href="https://tweakersnet/gallery/420420/wenslijst/">Wenslijst</a></li>
#
# 								<li class="divider"><a href="https://gatheringtweakersnet/forum/list_bookmarks">Forumbookmarks</a></li>
# 								<li><a href="https://gatheringtweakersnet/forum/find/poster/420420">Mijn topics</a></li>
#
# 								<li class="divider"><a href="https://tweakersnet/mytnet/karmastore/">Karmastore</a></li>
# 								<li><a href="https://tweakersnet/aboshop/">Word Abonnee</a></li>
# 								<li><a href="https://tweakersnet/instellingen/testpanel/">Testpanel</a></li>
#
# 								<li class="divider"><a href="https://tweakersnet/instellingen/layout/">Instellingen</a></li>
# 								<li><a href="https://tweakersnet/mytnet/logout/?location=https%3A//tweakersnet/reviews/4867/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml">Uitloggen</a></li>
# 							</ul>
# 						</div>
# 					</li>
# 					<li class="icon compare"><a title="Vergelijken">vergelijk items</a><span id="newCompareItemCount" class="newNotificationsCount">0</span></li>
# 					<li class="icon messages"><a title="Berichten" rel="popup:dmNotificationsPopup">berichten</a><span id="newDmNotificationsCount" class="newNotificationsCount">0</span></li>
# 					<li class="icon notifications"><a title="Notificaties" rel="popup:userNotificationsPopup">notificaties</a><span id="newNotificationsCount" class="newNotificationsCount">0</span></li>
# 					<li class="icon display flag nl"><a title="Weergave-opties" id="displayOptionsPopupButton" rel="popup:displayOptions" data-country="NL" data-autocolor="238">settings</a></li>
# 				</ul>
# 					</div><script>initDropDowns('#menu limore');</script>
# 				</div>
# 			</div>
# 			<div id="menubottombar">
# 				<div class="menubottom">
# 					<span class="slogan">Wij stellen technologie op de proef</span>
#
# 				<div class="socialcount">
# 					<a href="https://wwwfacebookcom/Tweakersnet" rel="external" class="facebook">
# 						<span class="arrow-left"></span>
# 						<span class="count">24,3K</span>
# 					</a>
# 					<a href="https://twittercom/tweakers" rel="external" class="twitter">
# 						<span class="arrow-left"></span>
# 						<span class="count">78,1K</span>
# 					</a>
# 				</div>
# 				</div>
# 			</div>
# 			<div id="searchbar">
# 				<div id="search">
#
# 					<a href="https://wwwtruenl/webhosting/" rel="external" id="true" title="Hosting door True"></a>
#
#
#
#
# 					<form action="https://tweakersnet/reviews/zoeken/" id="mainSearch" class="keywordSearch" onsubmit="trackEventWt('internalSearch',{2:'reviews'},true)"><div class="keyword"><input type="text" name="keyword" class="text" value="" placeholder="Zoek een review" onfocus="thisselect()"></div><input type="submit" class="submit" value="Zoeken"></form><script>var mainSearchSuggest=new SearchSuggest('reviews')</script>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="layout">
# 			<div id="contentArea">
# 				<div class="wrap">
# 					<div id="b_tb" class="leaderBoard async loading"><script>windowBannerManager && BannerManagerdisplayTag('tb')</script></div>
#
#
# 					<div id="header" class="articleHeading"><h1 class="ellipsis" itemprop="headline">Acer Swift 7 Preview - De dunste 13,3&quot;-notebook ooit</h1></div>
# 					<link itemprop="image" href="https://ictweakimgnet/ext/i/1303211688png">    <span itemprop="sourceOrganization" itemscope itemtype="http://schemaorg/Organization">
# 	<meta itemprop="name" content="Tweakers">
# 	<meta itemprop="url" content="https://tweakersnet/">
# 	<meta itemprop="logo" content="https://tweakersnet/logopng">
# </span>
#
# <div class="articleColumn">
#
#     <div class="article">
#
#         <p class="author">Door <a href="https://tweakersnet/plan/crew/347"><span itemprop="author">Wout Funnekotter</span></a>, <span itemprop="datePublished" content="2016-09-04T14:00:00+02:00">zondag 4 september 2016 14:00</span>, <a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml#reacties" rel="nofollow">87 reacties</a> &bull; <a target="_blank" class="feedback" href="https://gatheringtweakersnet/forum/list_topics/43" rel="nofollow">Feedback</a></p><div class="article" itemprop="articleBody"><p>Kijk je nu naar de het laptopaanbod in de Pricewatch, dan lijkt het niet meer dan normaal dat vrijwel elke laptopfabrikant mooie, dunne, strakke, aluminium modellen in de lineup heeft Een paar jaar terug was dat wel anders Uiteindelijk was het Intel dat&nbsp;met de introductie van het 'ultrabook'-concept de fabrikanten een schop onder de bips gaf en de lat hoger legde Toen we destijds modellen als de Asus Zenbook en Acer Aspire S7 voor het eerst vasthielden konden we ons niet voorstellen dat laptops ooit n&ograve;g dunner en lichter konden worden We zaten er compleet naast</p><p>Dit jaar lijkt eenzelfde ontwikkeling&nbsp;zich namelijk te herhalen Fabrikanten proberen elkaar de laatste tijd continu af te troeven met laptops die n&ograve;g dunner en n&ograve;g lichter zijn, waarbij tot nu toe gebruikelijke elementen als normale usb-poorten en video-uitgangen het veld hebben moeten ruimen Alles wordt er aan gedaan om laptops zo dun mogelijk te krijgen&nbsp;Apple heeft in deze klasse zijn 12" MacBook, HP kwam onlangs met zijn Spectre 13, Asus heeft de Zenbook 3 en nu op IFA heeft Acer zich bij deze club gevoegd met de Acer Swift 7, een laptop van nog geen centimeter dik die slechts iets meer dan een kilo weegt</p><p><a href="https://ictweakimgnet/ext/i/2001218813jpeg" rel="imageviewer"><img src="https://ictweakimgnet/ext/i/imagenormal/2001218813jpeg" alt="Acer Swift 7" width="620" height="413"></a></p><table border="0" cellspacing="0" cellpadding="0">
# <tbody>
# <tr>
# <th>&nbsp;</th>
# <th>Apple MacBook</th>
# <th>Asus Zenbook 3</th>
# <th>HP Spectre 13</th>
# <th>Acer Swift 7</th>
# </tr>
# <tr class="first">
# <td>Scherm</td>
# <td>12" <br>(2304x1440)</td>
# <td>12,5" <br>(1920x1080)&nbsp;</td>
# <td>13,3" <br>(1920x1080)</td>
# <td>13,3" <br>(1920x1080)</td>
# </tr>
# <tr>
# <td>Dikte</td>
# <td>13,1mm</td>
# <td>11,9mm</td>
# <td>10,4mm</td>
# <td>9,98mm</td>
# </tr>
# <tr>
# <td>Gewicht&nbsp;</td>
# <td>920g</td>
# <td>910g</td>
# <td>1,16kg</td>
# <td>1,1kg&nbsp;</td>
# </tr>
# <tr>
# <td>Aansluitingen&nbsp;</td>
# <td>1x usb-c&nbsp;</td>
# <td>1x usb-c</td>
# <td>3x usb-c</td>
# <td>2x usb-c</td>
# </tr>
# <tr>
# <td>Cpu</td>
# <td>Core M</td>
# <td>Core i7</td>
# <td>Core i7</td>
# <td>Core i5</td>
# </tr>
# <tr>
# <td>Accu&nbsp;</td>
# <td>41Wh</td>
# <td>40Wh</td>
# <td>38Wh</td>
# <td>&nbsp;?</td>
# </tr>
# </tbody>
# </table><p>De Swift 7 is onderdeel van een compleet nieuwe serie van Acer waarin ook Swift 1-, 3- en 5-modellen uit zullen komen, maar voor nu richtten we ons op het paradepaardje</p><p>Zetten we de specs van de voornaamste concurrenten naast elkaar dan is meteen duidelijk dat Acer inderdaad de claim mag maken van dunste laptop, al is het verschil met bijvoorbeeld een Spectre 13 minimaal Wellicht hadden de ontwerpers van Acer nog dunner gewild, maar dan waren de engineers vrijwel zeker gaan klagen In zijn huidige vorm is de Swift 7 namelijk niet veel dikker dan een usb-c-poort en het lijkt bijna onmogelijk om daar nog meer vanaf te snoepen</p><p>Van die usb-c-poorten heeft de Swift er twee Dat is gunstig omdat eentje gebruikt wordt om de laptop te laden en je niet wilt dat er dan geen mogelijkheid meer is om andere dingen aan te sluiten, zoals bij Apples MacBook Toch zul je in de praktijk ook bij de Swift 7 aan de slag moeten met verloopstekkers als je bijvoorbeeld een apparaat met usb-a-stekker wilt aansluiten, een ethernetkabel wilt inpluggen of een externe monitor wilt aansturen Dat is een beperking die je moet accepteren als je voor een laptop&nbsp;van dit formaat kiest</p><p><a href="https://ictweakimgnet/ext/i/2001218793jpeg" rel="imageviewer"><img class="alignCenter" src="https://ictweakimgnet/ext/i/imagenormal/2001218793jpeg" alt="Acer Swift 7" width="620" height="313"></a></p><p>Ondanks dat de behuizing nog geen centimeter dik is, lijkt Acer op het vlak van bouwkwaliteit weinig concessies gedaan te hebben De Swift 7 voelt stevig aan en is strak afgewerkt Zoals gebruikelijk bij een laptop in deze klasse geven de toetsen niet enorm veel feedback, maar we vonden ze alsnog fijner aanvoelen dan bijvoorbeeld de toetsen op een MacBook Ook het touchpad, dat lekker breed is, reageert goed De&nbsp;<em>duotone</em> kleurstelling&nbsp;met champagne en zwart ziet er prima uit, al hopen we dat er ook een wat klassiekere versie komt met een grijze kleur</p><p>Het 13,3"-scherm in de Swift 7 heeft een resolutie van 1920x1080 pixels en hoewel er genoeg laptops zijn met hogere resoluties snappen we de keuze van Acer goed Met zo weinig ruimte om te vullen binnenin het chassis zal de accu niet enorm groot zijn en een full-hd-scherm bespaart weer in de stroomconsumptie De glanzende afwerking van de display zorgt ervoor dat kleuren er mooi uitzien, maar het brengt ook extra reflecties met zich mee Bang voor vingervlekken hoef je niet te zijn want het scherm is niet aanraakgevoelig Gorilla Glass van Corning moet ervoor zorgen dat het scherm een tikje kan hebben</p><p>Acer meldt trots dat de Swift 7 een 'micro-bezel' heeft, oftewel een zeer&nbsp;kleine rand rondom het scherm Vergeleken met laptops van een paar jaar terug is dat misschien zo, maar anno 2016 is het formaat van de randen echt niet bijzonder Sterker nog, de eerdergenoemde concurrenten van deze laptop hebben schermranden die zelfs kleiner zijn</p><p><div class="articleImageGallery"><a href="https://ictweakimgnet/ext/i/imagelarge/2001218799jpeg" title="Acer Swift 7" class="thumb imagemedium" alt="Acer Swift 7" rel="imageviewer[set10833_1] external"><img src="https://ictweakimgnet/ext/i/imagemedium/2001218799jpeg" width=288 height=238 alt="Acer Swift 7"></a><a href="https://ictweakimgnet/ext/i/imagelarge/2001218803jpeg" title="Acer Swift 7" class="thumb imagemedium" alt="Acer Swift 7" rel="imageviewer[set10833_1] external"><img src="https://ictweakimgnet/ext/i/imagemedium/2001218803jpeg" width=288 height=238 alt="Acer Swift 7"></a><a href="https://ictweakimgnet/ext/i/imagelarge/2001218801jpeg" title="Acer Swift 7" class="thumb imagemedium" alt="Acer Swift 7" rel="imageviewer[set10833_1] external"><img src="https://ictweakimgnet/ext/i/imagemedium/2001218801jpeg" width=288 height=238 alt="Acer Swift 7"></a><a href="https://ictweakimgnet/ext/i/imagelarge/2001218807jpeg" title="Acer Swift 7" class="thumb imagemedium" alt="Acer Swift 7" rel="imageviewer[set10833_1] external"><img src="ht ...
#     </div>
#
#     <div id="reviewArticleButton">
# 			<div id="socialButtonsContainer">
# 				<a rel="popup:socialPopup" class="fancyButton grey largeText">
# 					<span class="button-image share"></span>
# 					Delen
# 				</a>
# 				<div id="shareButtonContent" style="display:none">
# 					<a href="https://twittercom/share?url=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml&amp;lang=en&amp;via=tweakers&amp;text=Acer+Swift+7+Preview%3A+de+dunste+13%2C3%22-notebook+ooit" class="shareImage twitter" onclick="windowopen(thishref,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=460,width=600');return false">Twitter</a> <a href="https://wwwfacebookcom/dialog/feed?app_id=188199811217403&amp;link=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml&amp;name=Acer+Swift+7+Preview%3A+de+dunste+13%2C3%22-notebook+ooit&amp;caption=&amp;redirect_uri=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml&amp;description=Acer+onthulde+op+IFA+een+nieuwe+lijn+notebooks+onder+de+naam+Swift+Volgens+de+fabrikant+is+het+13%2C3%22+Swift+7-model+de+dunste+notebook+van+dit+moment&amp;picture=https%3A%2F%2Fictweakimgnet%2Fext%2Fi%2F1303211688png" class="shareImage facebook" onclick="windowopen(thishref,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=400,width=1000');return false">Facebook</a> <a href="https://wwwlinkedincom/shareArticle?mini=true&amp;url=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml&amp;title=Acer+Swift+7+Preview%3A+de+dunste+13%2C3%22-notebook+ooit&amp;source=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml&amp;summary=Acer+onthulde+op+IFA+een+nieuwe+lijn+notebooks+onder+de+naam+Swift+Volgens+de+fabrikant+is+het+13%2C3%22+Swift+7-model+de+dunste+notebook+van+dit+moment" class="shareImage linkedin" onclick="windowopen(thishref,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=410,width=600');return false">LinkedIn</a> <a href="https://plusgooglecom/share?url=https%3A%2F%2Ftweakersnet%2Freviews%2F4867%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml" class="shareImage googleplus" onclick="windowopen(thishref,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=300,width=600');return false">Google+</a>
# 				</div>
# 			</div></div><div id="b_ac" class="advertorial async loading"><script>windowBannerManager && BannerManagerdisplayTag('ac')</script></div>
#     <br style="clear:both">
#
# </div>
#
#
# <div class="relevancyColumn">
#
#
# 			<div class="relatedAuthor greyTopBorderBlock">
# 				<h2 class="sectionhead">Door Wout Funnekotter</h2><span class="title"> - Hoofdredacteur</span><br><a class="thumb community author" href="https://tweakersnet/crew/347"><img src="https://ictweakimgnet/ext/i/2000572741jpeg" width=60 height=60 alt=""></a><p>Wout werkt sinds 2011 bij Tweakers en heeft zich lange tijd beziggehouden met het testen en recenseren van allerlei producten, met een nadruk op mobiele technologie Sinds augustus 2015 is hij hoofdredacteur In die rol werkt hij samen met de andere redacteuren eraan om de inhoud en presentatie van de site constant te verbeteren Wanneer de tijd het toelaat, schrijft hij nog wel eens een review</p><span class="authorSocial"><a class="readMore" href="https://twittercom/woutf">Volg Wout op Twitter</a></span><span class="authorSocial"><a class="readMore" href="https://plusgooglecom/+WoutFunnekotter/?rel=author">Volg Wout op Google+</a></span>
# 			</div>
# 			<div class="relationboxBlock greyTopBorderBlock">
# 				<h2>Lees meer over</h2>
# 				<div class="relationbox toggleContent"><div class="rbProductlist">
# 				<div class="rbTopList">
# 			<div class="item">
# 				<a href="https://tweakersnet/pricewatch/581153/acer-swift-7html" title="Acer Swift 7" class="thumb normal"  rel="nofollow"><img src="https://ictweakimgnet/ext/i/thumb/2001218495jpeg" width=120 height=90 alt=""></a>
# 				<p class="desc">
#
# 					<a href="https://tweakersnet/pricewatch/581153/acer-swift-7html">Acer Swift 7</a>
# 				</p>
# 				<p class="price">
# 					<a href="https://tweakersnet/pricewatch/581153/acer-swift-7html" rel="nofollow">nog geen prijs</a>
# 				</p>
#
# 			</div>
# 				</div></div><div class="rbEntitylist"><ul><li><a href="https://tweakersnet/categorie/496/laptops/reviews/">Laptops</a></li><li><a href="https://tweakersnet/merk/47/acer/reviews/">Acer</a></li><li><a href="https://tweakersnet/tag/ifa+2016/reviews/">ifa 2016</a></li><li><a href="https://tweakersnet/merk/categorie/4/acer/laptops">Acer laptops</a></li></ul></div></div>
# 			</div><div id="b_re" class="async loading"><script>windowBannerManager && BannerManagerdisplayTag('re')</script></div>
# 			<div class="relatedContent greyTopBorderBlock">
# 				<h2>Gerelateerde content</h2><ul class="useVisitedState"><li><span class="date">31-08</span><a class="ellipsis" href="https://tweakersnet/nieuws/115145/acer-introduceert-1-centimeter-dikke-laptop-in-nieuwe-swift-seriehtml" title="Acer introduceert 1-centimeter dikke laptop in nieuwe Swift-serie">Nieuws - <span>Acer introduceert 1-centimeter dikke laptop in nieuwe Swift-serie</span></a></ul></div>
# </div>
#
#
# 				<div id="commentColumn" class="greyTopBorderBlock">
# 					<div id="reacties"><div class="layoutFilter"><a href="https://tweakersnet/info/faq/moderatiesysteem/" title="Moderatie-faq" rel="nofollow">Moderatie-faq</a><span class="bullet">&bull;</span>
# 			<a rel="popup:reactionSortPopup" style="cursor: pointer;">Wijzig weergave</a>
# 			<div id="reactionSortForm" style="display: none;">
# 				<form id="sortForm" name="reactionSortForm" action="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=0&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" method="get">
# 					<h4>Sorteer op:</h4>
# 					<input type="radio" name="sort" value="rating-desc" id="rating-desc" checked><label for="rating-desc">Kwaliteit - beste threads eerst</label><br><input type="radio" name="sort" value="rating-asc" id="rating-asc"><label for="rating-asc">Kwaliteit - slechtste threads eerst</label><br><input type="radio" name="sort" value="time-asc" id="time-asc"><label for="time-asc">Tijd - oudste threads eerst</label><br><input type="radio" name="sort" value="time-desc" id="time-desc"><label for="time-desc">Tijd - nieuwste threads eerst</label><br>
# 					<!-- these two hidden fields are overwritten via JS -->
# 					<input type="hidden" name="orderBy" id="orderByField" value="rating">
# 					<input type="hidden" name="order" id="orderField" value="desc">
# 					<input type="hidden" name="niv" value="0">
# 					<br>
# 					<h4>Weergave:</h4>
# 					<input type="radio" name="mode" value="nested" id="nested" checked><label for="nested">Threaded</label><br><input type="radio" name="mode" value="flat" id="flat"><label for="flat">Plat</label><br>
# 					<br>
# 					<input type="button" id="reactionSortChangeButton" class="fancyButton" value="Wijzig">
# 					&nbsp;
# 					<input type="button" id="reactionSortSaveButton" class="fancyButton grey" value="Opslaan in voorkeuren">
# 					<img id="reactionSortThrobber" style="float:right; display:none;" src="https://tweakimgnet/g/if/icons/throbbergif" alt="Bezig met opslaan">
# 					<br>
# 					<br>
# 				</form>
# 			</div>
# 			<script>initReactionSort();</script></div><h2>Reacties <small>(87)</small></h2><div class="filterBox"><div class="modFilter" data-currentLevel="0"><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=-1&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small ">-1</span></a><span class="reactionCount score-1">87</span><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=0&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small score0">0</span></a><span class="reactionCount score0">82</span><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=1&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small score1">+1</span></a><span class="reactionCount score1">60</span><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=2&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small score2">+2</span></a><span class="reactionCount score2">5</span><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=3&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small score3">+3</span></a><span class="reactionCount score3">1</span><a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?mode=nested&amp;niv=none&amp;order=desc&amp;orderBy=rating&amp;page=1#reacties" rel="nofollow popup:reactionRatingFilterPopup"><span class="scoreButton small wide ">Ongemodereerd</span></a><span class="reactionCount scorenone">1</span></div></div><div id="reactieContainer"><div id="r_8976827" class="reactie" data-reaction-id="8976827" data-owner-id="468857" data-token="53d06685cf523edfa0caccfb63e6975a75a5334f">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/468857/" class="userLink" rel="nofollow">Mediokas</a> <br>
#
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976827#r_8976827" class="date" rel="nofollow">4 september 2016 14:18</a><!-- scorer: 32,30 --></div>
# 				<div class="reactieContent">
# 					Ik houd best van een mooie kleine strakke laptop, maar de trend wordt nu wel wat overdreven imo Ik heb dagelijks een laptop mee naar m'n werk en ik sleep hem van hot naar her Een laptop van 2 kilo die wat dikker is, is hier ook prima geschikt voor Wat belangrijk is, is dat ik een HDMI aansluiting heb, zodat ik hem snel op externe schermen kan aansluiten Ook voldoende usb aansluitingen zijn voor mij belangrijk <br>
# <br>
# Mooie apparaten, maar ik begin me af te vragen of de voordelen van ligt en compact nu niet zo belangrijk worden gemaakt, dat essentiële andere zaken eronder gaan lijden Voor wie is dit nou nog nuttig?
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976827/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8976889" class="reactie" data-reaction-id="8976889" data-owner-id="163841" data-token="9ead2409cf9ae44627d07667fb4ac9f3f69589a1">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/163841/" class="userLink" rel="nofollow">iceheart</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976827#r_8976827" class="replyTo" rel="nofollow">@Mediokas</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976889#r_8976889" class="date" rel="nofollow">4 september 2016 14:50</a><!-- scorer: 46,70 --></div>
# 				<div class="reactieContent">
# 					Poeh, hoe moeilijk was het geweest een micro-hdmi poortjes in te bouwen als ze wel iets op jou(w doelgroep) toegespitst hadden willen maken?<br>
# Het kán echt wel <br>
# <br>
# En van de andere kant bezien: zodra ik aan m'n bureau zit gaat de laptop toch aan een dock met alle (grote) randapparatuur die ik maar wil hebben; waarom zou ik een gram meer dan nodig naar meetings meeslepen? En is een verloopstekkertje (dp-over-usb-c, actieve dp-hdmiconverter) nu echt zo lastig mocht miracast nog geen optie zijn? <br>
# Ik heb echt liever dit; ook die 2kg laptop is te klein en dun (tobo travel) om lang echt lekker te werken - dan zit ik alsnog aan die dock vast<br>
# Ik reis wél met het OV (er zijn routes die met de auto nog rotter zijn dan met OV of fiets <img src="//tweakimgnet/g/s/clowngif" width="15" height="15" alt=":+"> ) en ik zie het wel zitten (al pak ik dan persoonlijk liever m'n surface pro maar dat maakt mij dan ook wél de doelgroep <img src="//tweakimgnet/g/s/smilegif" width="15" height="15" alt=":)"> )
# 					<p class="edit">[Reactie gewijzigd door iceheart op 4 september 2016 14:50]</p>
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976889/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8977113" class="reactie" data-reaction-id="8977113" data-owner-id="216576" data-token="4e5b3f38ce2f8e5e075519642366cfbcf3d27279">
# 				<div class="reactieBody informative">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score2" title="Gemiddelde beoordeling: +2">+2</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/216576/AlfaGTjpg" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/216576/" class="userLink" rel="nofollow">4Lph4Num3r1c</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976889#r_8976889" class="replyTo" rel="nofollow">@iceheart</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977113#r_8977113" class="date" rel="nofollow">4 september 2016 16:24</a><!-- scorer: 134,00 --></div>
# 				<div class="reactieContent">
# 					hij heeft meerdere USB-C connectoren Dat is de nieuwe connector, die je straks op vrijwel alles aan kunt sluiten <br>
# <br>
# Ook op je monitor (Overigens kun je vervolgens dan zaken als toetsenbord en muizen weer op het scherm aansluiten), zodat je zelfs maar 1 kabeltje nodig hebt En ondertussen gebruikt je laptop dat ene kabeltje ook nog om zichzelf op te laden<br>
# <br>
# Dus nee het is geen achteruitgang dat er geen ouderwetse HDMI opzit, maar juist vooruitgang dat alles van de toekomst er al op zit (en mocht je echt nog een HDMI apparaatje aan willen sluiten, is daar gewoon een verlooplabeltje voor te krijgen)
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977113/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8977219" class="reactie" data-reaction-id="8977219" data-owner-id="553740" data-token="eee08ee45573d935cc659cfe49534497eeab8945">
# 				<div class="reactieBody spotlight nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score3" title="Gemiddelde beoordeling: +3">+3</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/553740/crop57b34226bf551_croppedjpeg" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/553740/" class="userLink" rel="nofollow">GJFVV</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977113#r_8977113" class="replyTo" rel="nofollow">@4Lph4Num3r1c</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977219#r_8977219" class="date" rel="nofollow">4 september 2016 17:27</a><!-- scorer: 180,00 --></div>
# 				<div class="reactieContent">
# 					USB C is alleen een type connector dat zegt in principe niets over de poort erachter Er kan in het slechtste geval zelfs gewoon een USB 2 poort achter zitten  <img src="//tweakimgnet/g/s/clowngif" width="15" height="15" alt=":+"> <a href="https://tweakersnet/reviews/4647/de-veelbelovende-warboel-van-usb-c-een-kabel-die-vrijwel-alles-kanhtml" rel="external">reviews: De veelbelovende warboel van usb-c: Eén kabel die vrijwel alles kan</a><br>
# <br>
# Niet dat dit hier het geval zal zijn  <img src="//tweakimgnet/g/s/bonkgif" width="30" height="17" alt="8)7"> <br>
# <br>
# In die zin zegt zo'n tabel zoals hierbovenb waarin de laptops worden vergeleken ook niet veel wat betreft de aansluitmogelijkheden  <img src="//tweakimgnet/g/s/nosmile2gif" width="15" height="15" alt=":|">
# 					<p class="edit">[Reactie gewijzigd door GJFVV op 4 september 2016 17:32]</p>
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977219/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div></div><div id="r_8977359" class="reactie" data-reaction-id="8977359" data-owner-id="440316" data-token="54cfc7b15edff2024354fcfaebda0843b38a2e3b">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/440316/" class="userLink" rel="nofollow">Boskoe</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976889#r_8976889" class="replyTo" rel="nofollow">@iceheart</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977359#r_8977359" class="date" rel="nofollow">4 september 2016 18:59</a><!-- scorer: 5,00 --></div>
# 				<div class="reactieContent">
# 					Is dit <a href="http://wwwzdnetbe/nieuws/185631/hdmi-omarmt-usb-type-c/" rel="external nofollow" title="http://wwwzdnetbe/nieuws/185631/hdmi-omarmt-usb-type-c/">http://wwwzdnetbe/nieuws/185631/hdmi-omarmt-usb-type-c/</a> niet de ideale oplossing hiervoor?
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977359/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div></div><div id="r_8976835" class="reactie" data-reaction-id="8976835" data-owner-id="457607" data-token="64f1ba7a41cf94d114d27a4e11171e6976a10008">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/457607/" class="userLink" rel="nofollow">Fledder2000</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976827#r_8976827" class="replyTo" rel="nofollow">@Mediokas</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976835#r_8976835" class="date" rel="nofollow">4 september 2016 14:21</a><!-- scorer: 32,81 --></div>
# 				<div class="reactieContent">
# 					Mee eens Voor de meeste mensen wordt de draagbaarheid van een laptop overdreven De meeste mensen lopen hooguit een paar honderd meter per dag met zo'n ding, en wat maakt dan een kilo of minder verschil nog uit?
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976835/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8977105" class="reactie" data-reaction-id="8977105" data-owner-id="119419" data-token="6e2d1d3fe2a267241758805976e56d4b8153fb2e">
# 				<div class="reactieBody informative">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score2" title="Gemiddelde beoordeling: +2">+2</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/119419/candc-60pxgif" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/119419/" class="userLink" rel="nofollow">GekkePrutser</a> <a class="tweakersBadge" href="https://tweakersnet/aboshop/"><img src="https://tweakimgnet/g/abo/abonneesvg" width="13" height="14" title="Tweakers Plus"></a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976835#r_8976835" class="replyTo" rel="nofollow">@Fledder2000</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977105#r_8977105" class="date" rel="nofollow">4 september 2016 16:22</a><!-- scorer: 81,50 --></div>
# 				<div class="reactieContent">
# 					Als het je enige laptop is, dan maakt het je wellicht niet zo veel uit Maar ik reis veel voor mijn werk en dan neem ik regelmatig (vooral op de langere trips) een eigen apparaat mee Op de kortere trips is dat een tablet (Sony Z2 10&quot; Tablet) maar op de langere trips op dit moment een Surface Pro 3 (met Linux erop)<br>
# <br>
# Dit omdat mijn werk laptop (HP 9470m) ten eerste een afgrijselijk scherm heeft, een waardeloze accuduur en er Windows op staat met allerlei rotte spyware van mijn werk (<small>Al heb ik er stiekem wel een mSATA SSD naast gezet met Linux  <img src="//tweakimgnet/g/s/hypocritegif" width="12" height="16" alt="O-)">, maar dat lost het scherm/accu probleem niet op)</small><br>
# <br>
# 2 laptops van 15-2kg plus kleren plus de koffer zelf gaat niet in de 10kg handbaggage passen (en ik heb al een stevige koffer van een kilo of 3 omdat ik zo veel reis) Een laptop onder de kilo is dan ook broodnodig om toch iets werkbaars voor prive doeleinden te hebben onderweg
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977105/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8978267" class="reactie" data-reaction-id="8978267" data-owner-id="468857" data-token="5f8d5d8cb92e7be43fd2dd986f2177d18a6faaac">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/468857/" class="userLink" rel="nofollow">Mediokas</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977105#r_8977105" class="replyTo" rel="nofollow">@GekkePrutser</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8978267#r_8978267" class="date" rel="nofollow">5 september 2016 09:30</a><!-- scorer: 5,00 --></div>
# 				<div class="reactieContent">
# 					Hmmm, er zijn dus wel mensen die dit graag zien Ik vind de situatie wel erg specifiek en kan me niet voorstellen dat dit voor veel mensen zo is Toch is het een echte trend, terwijl de markt imo erg klein is Heb toch het gevoel dat veel mensen zo'n ding kopen voor de wauw factor Maar in functionaliteit mis je toch echt wel veel belangrijke zaken
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8978267/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div></div><div id="r_8976899" class="reactie" data-reaction-id="8976899" data-owner-id="473559" data-token="cee8b4d65fe793f4c89ebd4ec20f7dc043abbcb9">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/473559/" class="userLink" rel="nofollow">killerfromsky</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976835#r_8976835" class="replyTo" rel="nofollow">@Fledder2000</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976899#r_8976899" class="date" rel="nofollow">4 september 2016 14:52</a><!-- scorer: 6,20 --></div>
# 				<div class="reactieContent">
# 					Ik snap die hele evolutie ook niet echt, een 13&quot; laptop is toch een mooi formaat? De voetprint is voor mij veel belangrijker dan de dikte<br>
# <br>
# Ik heb liever een iets dikkere laptop, met betere koeling en dus zonder thermal throttle Sommige van de ultrabooks throttlen al voordat ze aan hun 15watt TDP zitten, zonde toch?
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976899/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8976969" class="reactie" data-reaction-id="8976969" data-owner-id="161314" data-token="d736da75f1fb86509114458327c836f4ce4d7641">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score1" title="Gemiddelde beoordeling: +1">+1</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/161314/1285883144966jpg" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/161314/" class="userLink" rel="nofollow">Annihilism</a><div class="karmaCards"><ul id="karma_8976969" class="topKarma single">
# 			<li title="Acer" class="labelCard item1 level8 alltime"><a rel="popup:karmaPopup" class="ellipsis" data-itemidentifier="48-47" data-userid="161314"><img width="9" height="11" title="karmakoning" src="https://tweakimgnet/g/karma/kingsvg">Acer</a></li></ul></div> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976899#r_8976899" class="replyTo" rel="nofollow">@killerfromsky</a> &bull;
# ...
# Ik heb van de mijne direct na ontvangst alle partities verwijderd en van een degelijke en stabiele OS voorzien; Ubuntu<br>
# <br>
# Uiteindelijk gaat het mij voornamelijk om de hardware
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977503/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div></div></div></div></div><div id="r_8976927" class="reactie" data-reaction-id="8976927" data-owner-id="355158" data-token="b55d90d3d7c9edca790c5076ee19731649e6ff95">
# 				<div class="reactieBody hidden">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton modDisabled reason8 score-1" title="Gemiddelde beoordeling: -1">-1</a>
#
# 					<a href="https://tweakersnet/gallery/355158/" class="userLink" rel="nofollow">Carni</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976813#r_8976813" class="replyTo" rel="nofollow">@fishy</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976927#r_8976927" class="date" rel="nofollow">4 september 2016 15:09</a><!-- scorer: -21,80 --></div>
# 				</div><div id="r_8976931" class="reactie" data-reaction-id="8976931" data-owner-id="16422" data-token="284d290aaed41dcd9c3823456d107fe40ef8f7e5">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score0" title="Gemiddelde beoordeling: 0">0</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/16422/atariJPG" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/16422/" class="userLink" rel="nofollow">nexhil</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976927#r_8976927" class="replyTo" rel="nofollow">@Carni</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976931#r_8976931" class="date" rel="nofollow">4 september 2016 15:11</a><!-- scorer: -6,00 --></div>
# 				<div class="reactieContent">
# 					Alleen het stuk fruit wat Apple er op zet doet geen afbreuk aan het ontwerp <img src="//tweakimgnet/g/s/smilegif" width="15" height="15" alt=":)">
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976931/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8976951" class="reactie" data-reaction-id="8976951" data-owner-id="327457" data-token="e9b49da8ca23b4e81d077b9264626018416cc325">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score0" title="Gemiddelde beoordeling: 0">0</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/327457/" class="userLink" rel="nofollow">computergek80</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976931#r_8976931" class="replyTo" rel="nofollow">@nexhil</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976951#r_8976951" class="date" rel="nofollow">4 september 2016 15:19</a><!-- scorer: 0,00 --></div>
# 				<div class="reactieContent">
# 					En het stuk fruit zit niet onder het beeldscherm
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976951/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8976985" class="reactie" data-reaction-id="8976985" data-owner-id="355158" data-token="8a2697a56955d4726f5d47c14e3d086a457441cc">
# 				<div class="reactieBody">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score0" title="Gemiddelde beoordeling: 0">0</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/355158/crop575b478b97ccbpng" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/355158/" class="userLink" rel="nofollow">Carni</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976951#r_8976951" class="replyTo" rel="nofollow">@computergek80</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976985#r_8976985" class="date" rel="nofollow">4 september 2016 15:30</a><!-- scorer: 0,00 --></div>
# 				<div class="reactieContent">
# 					<blockquote><div class="quote">En het stuk fruit zit niet onder het beeldscherm</div></blockquote><a href="https://wwwgooglenl/search?q=imac&amp;espv=2&amp;biw=900&amp;bih=1315&amp;tbm=isch&amp;tbo=u&amp;source=univ&amp;sa=X&amp;ved=0ahUKEwjBiavj6PXOAhUQnRQKHUK7DCsQsAQIXA" rel="external nofollow" title="https://wwwgooglenl/search?q=imac&amp;espv=2&amp;biw=900&amp;bih=1315&amp;tbm=isch&amp;tbo=u&amp;source=univ&amp;sa=X&amp;ved=0ahUKEwjBiavj6PXOAhUQnRQKHUK7DCsQsAQIXA">https://wwwgooglenl/seaPXOAhUQnRQKHUK7DCsQsAQIXA</a>
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8976985/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div><div id="r_8977047" class="reactie" data-reaction-id="8977047" data-owner-id="327457" data-token="1e7d9d48591c9de9f26b8291322240b6b4d7fd2a">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score0" title="Gemiddelde beoordeling: 0">0</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/327457/" class="userLink" rel="nofollow">computergek80</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976985#r_8976985" class="replyTo" rel="nofollow">@Carni</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977047#r_8977047" class="date" rel="nofollow">4 september 2016 15:55</a><!-- scorer: 0,00 --></div>
# 				<div class="reactieContent">
# 					Ah, maar dat is de iMac Ik vind die zelf al wat minder mooi, juist omdat het logo wel onder het scherm is Maar omdat het geen tekst is leidt het al veel minder af dam bijvoorbeeld &quot;Acer&quot;
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977047/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div></div></div><div id="r_8977093" class="reactie" data-reaction-id="8977093" data-owner-id="649556" data-token="b9f8ee3d997c930b1060106b236b13f730eb956e">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled score0" title="Gemiddelde beoordeling: 0">0</a>
# 					<span class="thumb usericonsmall"><img src="https://ictweakimgnet/usericons/649556/60x60-zl3jpg" width=30 height=30 alt=""></span>
# 					<a href="https://tweakersnet/gallery/649556/" class="userLink" rel="nofollow">Djoetma</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976931#r_8976931" class="replyTo" rel="nofollow">@nexhil</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977093#r_8977093" class="date" rel="nofollow">4 september 2016 16:15</a><!-- scorer: 0,00 --></div>
# 				<div class="reactieContent">
# 					Dit komt natuurlijk door de associatie met het merk en niet omdat het zo'n mooi logo is
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8977093/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div><div id="r_8976945" class="reactie" data-reaction-id="8976945" data-owner-id="355158" data-token="0f25d8855ce04604609786392f83be51c8d1a595">
# 				<div class="reactieBody nochilds hidden">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton modDisabled reason8 score-1" title="Gemiddelde beoordeling: -1">-1</a>
#
# 					<a href="https://tweakersnet/gallery/355158/" class="userLink" rel="nofollow">Carni</a> <br>
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976931#r_8976931" class="replyTo" rel="nofollow">@nexhil</a> &bull;
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8976945#r_8976945" class="date" rel="nofollow">4 september 2016 15:17</a><!-- scorer: -20,00 --></div>
# 				</div></div></div></div></div><div id="r_8978407" class="reactie" data-reaction-id="8978407" data-owner-id="698741" data-token="c2cfd88b8e5e3a93184e14597c4a880c373817ed">
# 				<div class="reactieBody nochilds">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton large modEnabled" title="Deze reactie is nog niet beoordeeld">0</a>
# 					<span class="thumb usericonsmall empty"><!-- no image available --></span>
# 					<a href="https://tweakersnet/gallery/698741/" class="userLink" rel="nofollow">Brousant</a> <br>
#
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8978407#r_8978407" class="date" rel="nofollow">5 september 2016 10:08</a><!-- scorer: 0,00 --></div>
# 				<div class="reactieContent">
# 					&quot;Wellicht hadden de ontwerpers van Acer nog dunner gewild, maar dan waren de engineers vrijwel zeker gaan klagen&quot;<br>
# <br>
# Reken maar dat de engineers hebben geklaagd, industrial designers maken vaker wel dan niet een eerste ontwerp waarbij nauwelijks rekening is gehouden met de elektronica die ook nog in de behuizing moet
#
# 				</div><div class="reactieFooter"><a href="https://tweakersnet/reacties/bekijk/8978407/" class="commentLink" rel="nofollow">Reageer</a></div>
# 				</div></div><div id="r_8977319" class="reactie" data-reaction-id="8977319" data-owner-id="301518" data-token="5f7a4e0131d0d56dc3e9f0a4c4b1f2f573d909f1">
# 				<div class="reactieBody nochilds hidden">
# 					<div class="reactieHeader">
#
# 					<a rel="popup:modPopup login:reload" class="scoreButton modDisabled reason8 score-1" title="Gemiddelde beoordeling: -1">-1</a>
#
# 					<a href="https://tweakersnet/gallery/301518/" class="userLink" rel="nofollow">Rixilabur</a> <br>
#
# 					<a href="https://tweakersnet/reviews/4867/last/acer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooithtml?showReaction=8977319#r_8977319" class="date" rel="nofollow">4 september 2016 18:34</a><!-- scorer: -20,00 --></div>
# 				</div></div><form class="reactie" id="reactieForm" action="https://tweakersnet/reacties/nieuw/" method="POST">
#
# 					<fieldset>
# 						<legend>Reactie formulier</legend>
# 						<label for="reactieFormContent">Reageer:</label>
# 						<textarea name="reactieFormContent" id="reactieFormContent" tabindex="4"></textarea>
# 						<div class="submit">
# 							<input type="submit" value="Plaats reactie" class="fancyButton" id="reactionFormSubmit" accesskey="s" tabindex="5">
# 						</div>
# 						<input type="hidden" name="action" value="new_message">
# 						<input type="hidden" name="tabel" value="18">
# 						<input type="hidden" name="tabelid" value="4867">
# 						<input type="hidden" name="parentid" value="0">
# 						<input type="hidden" name="tweakers_token" value="onw998E8V81boGy7LM0vgKc6CYtUvzzAYzpYRqxi">
# 					</fieldset>
# 				</form></div></div></div><br class="clear"><script>windowreactionForm = new ReactionForm(3,0,false,false);</script>    <script>initArticleBehaviours();</script>
#
# 					<div class="clear"></div>
# 				</div>
# 			</div>
# 		</div>
# 			<div id="bottom">
# 				<div class="hr"><hr></div>
#
# 			<div id="ticker">
# 				<p><a href="https://tweakersnet/pricewatch/553627/apple-ios-10html">Apple iOS 10</a> <a href="https://tweakersnet/product/512905/microsoft-xbox-one-s/">Microsoft Xbox One S</a> <a href="https://tweakersnet/product/511795/fifa-17/">FIFA 17</a> <a href="https://tweakersnet/pricewatch/395213/sony-playstation-vrhtml">Sony PlayStation VR</a> <a href="https://tweakersnet/pricewatch/548201/amd-radeon-rx-480-4gbhtml">AMD Radeon RX 480 4GB</a> <a href="https://tweakersnet/product/498943/battlefield-1/">Battlefield 1</a> <a href="https://tweakersnet/pricewatch/553637/google-android-nougathtml">Google Android Nougat</a> <a href="https://tweakersnet/product/511977/watch-dogs-2/">Watch Dogs 2</a>
# 				</p>
# 			</div>
# 				<div id="about">
# 					<ul class="bulletSeparatedList">
# 						<li><a href="https://tweakersnet/info/advertising/">Adverteren</a></li>
# 						<li><a href="https://tweakersnet/contact/">Contact</a></li>
# 						<li><a href="https://tweakersnet/devicedetect/">Weergaveopties</a></li>
# 						<li><a href="https://tweakersnet/info/over_tweakers/">Over Tweakers</a></li>
# 						<li><a href="https://tweakersnet/privacy/">Jouw privacy</a></li>
# 						<li><a href="https://tweakersnet/voorwaarden/">Algemene voorwaarden</a></li>
# 						<li><a href="https://tweakersnet/cookies/">Cookies</a></li>
# 						<li><a onclick="loadUsabilla()">Feedback</a></li>
# 					</ul>
# 					<p class="social">
# 						<a href="https://twittercom/tweakers" rel="external" class="button twitter"><span>Volg @tweakers</span></a>
# 						<a href="https://wwwfacebookcom/Tweakersnet" rel="external" class="button facebook"><span>Like Tweakers</span></a>
# 						<a href="https://tweakersnet/feeds/mixedxml" class="button rss"><span>Rss-feeds</span></a>
# 					</p>
# 					<p class="wvhj">
# 						<a href="https://tweakersnet/plan/905/tweakers-valt-in-de-prijzen-bij-website-van-het-jaar-verkiezinghtml" title="Website van het jaar 2015"></a>
# 					</p>
# 					<p class="colofon">
# 						&copy; 1998 - 2016 de Persgroep Online Services BV
# 						<span class="seperator">&bull;</span>
# 						<a href="https://tweakersnet/">Tweakers</a> vormt samen met oa <a href="https://wwwautotracknl/" rel="external">Autotrack</a> en <a href="https://wwwcarsomnl/" rel="external">Carsomnl</a> de Persgroep Online Services BV
# 						<span class="seperator">&bull;</span>
# 						Hosting door <a href="https://wwwtruenl/vps/" title="VPS hosting" rel="external">True</a>
# 					</p>
#
# 				</div>
# 			</div><div id="tracker"></div><script>Trackerinit({"visible":false,"fixed":false,"position":"l"})</script>		<script>
# 			if(windowResponsive)Responsivebootstrap();
# 			if(windowTracker)Trackerrefresh();
# 			if(windowcompareStorage)compareStorageinit();
# 			if(windowBehaviourManager)BehaviourManagerexec();
# 			if(windowNotificationNotifier)NotificationNotifierinit();
# 		</script>
# 		<div id="b_ist" class="adLoader"><script>windowBannerManager && BannerManagerdisplayTag('ist')</script></div>
# 		<noscript><img src="https://vnumedia01webtrekknet/318816705845986/wt?p=328,reviews%2Farticle%2Facer-swift-7-preview-de-dunste-13-komma-3-inch-notebook-ooit&amp;cg1=tweakersnet&amp;cg2=Reviews&amp;cg3=Computers&amp;cg4=Computers&amp;cg5=Laptops&amp;cg6=Preview&amp;cp1=A&amp;cp3=1472990400&amp;cp4=ifa%202016&amp;cp5=Acer&amp;cp6=Wout%20Funnekotter&amp;cp7=Acer%20Swift%207%20Preview%3A%20de%20dunste%2013%2C3%22-notebook%20ooit" width=1 height=1 alt=""></noscript>
# 		<!-- Request ID: Plutus_2927_57cd3f8022df8473832055, Server time: 0,0775 s (C: 0,0621; Q: 9; 0,0068; E: 7; 0,0072 s, M: 8; 0,0021 s, A: 0; 0,0000 s), Mem: 14552 KB, User: fazzeh, Engines: (S) plutus (7) -->
# 	</body>
# </html>
